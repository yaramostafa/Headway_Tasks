# %%
# pip install dask
# pip install "dask[diagnostics]" --upgrade

# %%
from platform import python_version

print(python_version())
# Out:
# 3.11.10

# %% [markdown]
# # Dask practice
# * [Dask Vs Pandas](#third-bullet)
# * [Dataframes](#second-bullet)

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv("weather_data.csv")
df
# Out:
# Dask DataFrame Structure:
#                   day temperature windspeed   event
# npartitions=1
#                object       int64     int64  object
#                   ...         ...       ...     ...
# Dask Name: read-csv, 1 graph layer

# %%
df.head()
# Out:
#           day  temperature  windspeed  event
# 0  2024-01-01           32          6   Rain
# 1  2024-01-02          -35          7  Sunny
# 2  2024-01-03           28          2   Snow
# 3  2024-01-04           24          7   Snow
# 4  2024-01-05           32          4   Rain

# %% [markdown]
# ## Dask Vs Pandas <a class="anchor" id="third-bullet"></a>

# %%
import pandas as pd
import dask.dataframe as dd
import time

# %%
# pandas

start_time = time.time()
pandas_df = pd.read_excel('oilgas.xlsx')

pandas_filtered_df = pandas_df[pandas_df['NormalizedOilEUR'] > 50]

pandas_grouped_df = pandas_df.groupby('FormationAlias').agg({'NormalizedOilEUR': 'mean'})

pandas_time = time.time() - start_time
print(f"Pandas operations took {pandas_time:.2f} seconds")
# Out:
# Pandas operations took 12.15 seconds

# %%
# Dask 

pandas_df = pd.read_excel('oilgas.xlsx')
start_time = time.time()
dask_df = dd.from_pandas(pandas_df, npartitions=4)

dask_filtered_df = dask_df[dask_df['NormalizedOilEUR'] > 50]

dask_grouped_df = dask_df.groupby('FormationAlias').agg({'NormalizedOilEUR': 'mean'})

dask_result = dask_grouped_df.compute()

dask_time = time.time() - start_time
print(f"Dask operations took {dask_time:.2f} seconds")

# Memory Comparison
print(f"Pandas memory usage: {pandas_df.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
# Out:
# Dask operations took 0.01 seconds
# Pandas memory usage: 2.60 MB

# %%
dask_df
# Out:
# Dask DataFrame Structure:
#               WellID     BVHH FormationAlias   NioGOR   CodGOR LateralLength ProppantPerFoot FluidPerFoot LeftDistance LeftNeighbourType RightDistance RightNeighbourType      TVD NormalizedOilEUR NormalizedGasEUR
# npartitions=4
# 0              int64  float64         object  float64  float64       float64         float64      float64      float64            object       float64             object  float64          float64          float64
# 2302             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# 4604             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# 6905             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# 9205             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# Dask Name: from_pandas, 1 graph layer

# %% [markdown]
# ## Dask DataFrames <a class="anchor" id="second-bullet"></a>

# %%
import dask.dataframe as dd
import pandas as pd

# %%
df = pd.read_excel('oilgas.xlsx')
ddf = dd.from_pandas(df, npartitions=4)
ddf._meta # Many DataFrame operations rely on knowing the name and dtype of columns.
# Out:
# Empty DataFrame
# Columns: [WellID, BVHH, FormationAlias, NioGOR, CodGOR, LateralLength, ProppantPerFoot, FluidPerFoot, LeftDistance, LeftNeighbourType, RightDistance, RightNeighbourType, TVD, NormalizedOilEUR, NormalizedGasEUR]
# Index: []

# %%
ddf._meta.dtypes
# Out:
# WellID                  int64
# BVHH                  float64
# FormationAlias         object
# NioGOR                float64
# CodGOR                float64
# LateralLength         float64
# ProppantPerFoot       float64
# FluidPerFoot          float64
# LeftDistance          float64
# LeftNeighbourType      object
# RightDistance         float64
# RightNeighbourType     object
# TVD                   float64
# NormalizedOilEUR      float64
# NormalizedGasEUR      float64
# dtype: object

# %%
ddf._meta_nonempty
# Out:
#    WellID  BVHH FormationAlias  NioGOR  CodGOR  LateralLength  \
# 0       1   1.0            foo     1.0     1.0            1.0
# 1       1   1.0            foo     1.0     1.0            1.0
#
#    ProppantPerFoot  FluidPerFoot  LeftDistance LeftNeighbourType  \
# 0              1.0           1.0           1.0               foo
# 1              1.0           1.0           1.0               foo
#
#    RightDistance RightNeighbourType  TVD  NormalizedOilEUR  NormalizedGasEUR
# 0            1.0                foo  1.0               1.0               1.0
# 1            1.0                foo  1.0               1.0               1.0

# %%
ddf.describe().compute()
# Out:
#              WellID         BVHH         NioGOR        CodGOR  LateralLength  \
# count  9.206000e+03  7565.000000    8709.000000   7538.000000    9206.000000
# mean   7.183554e+08     1.031013    4699.704950   4219.441933    6970.061820
# std    9.295257e+08     0.370794   12584.166286   3306.948828    2673.528748
# min    5.001097e+08    -0.125405      85.752059    336.475960    1749.000000
# 25%    5.123371e+08     0.822785    2603.961103   2581.020606    4310.000000
# 50%    5.123406e+08     1.114846    3912.059746   3745.217424    7210.000000
# 75%    5.123448e+08     1.366772    5024.250073   5364.540326   10101.000000
# max    4.902129e+09     2.260032  357894.183679  26193.592720   16676.000000
#
#        ProppantPerFoot  FluidPerFoot  LeftDistance  RightDistance  \
# count      8974.000000   8942.000000   6758.000000    6778.000000
# mean       1013.557032   1035.336411    864.819473     877.969608
# std         529.759630    629.271011    925.304147     947.646937
# min           0.000000      0.001171     14.000000      14.000000
# 25%         782.479378    768.361919    360.000000     363.000000
# 50%         985.414101    969.383008    682.000000     687.000000
# 75%        1503.474881   1677.035920   1006.750000    1073.500000
# max       10217.314931  20117.640692   5275.000000    5276.000000
#
#                TVD  NormalizedOilEUR  NormalizedGasEUR
# count  8893.000000       9206.000000       9206.000000
# mean   7013.938041         19.033831        105.802192
# std     616.775613          8.187220         66.225371
# min    2610.000000          0.000000          0.000000
# 25%    6924.500000         14.387473         72.930225
# 50%    7065.000000         18.433993        120.438532
# 75%    7684.500000         24.034652        164.555622
# max    9793.000000         96.959244        465.849396

# %%
ddf.npartitions
# Out:
# 4

# %%
ddf.divisions
# Out:
# (0, 2302, 4604, 6905, 9205)

# %%
ddf.loc[2202:4004]  # inspects first two partitions
# Out:
# Dask DataFrame Structure:
#               WellID     BVHH FormationAlias   NioGOR   CodGOR LateralLength ProppantPerFoot FluidPerFoot LeftDistance LeftNeighbourType RightDistance RightNeighbourType      TVD NormalizedOilEUR NormalizedGasEUR
# npartitions=2
# 2202           int64  float64         object  float64  float64       float64         float64      float64      float64            object       float64             object  float64          float64          float64
# 2302             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# 4004             ...      ...            ...      ...      ...           ...             ...          ...          ...               ...           ...                ...      ...              ...              ...
# Dask Name: loc, 2 graph layers

# %%
ddf.divisions # often we do not have such information about our partition when reading CSV files use df.set_index(...)
# Out:
# (0, 2302, 4604, 6905, 9205)

# %%
ddf.columns
# Out:
# Index(['WellID', 'BVHH', 'FormationAlias', 'NioGOR', 'CodGOR', 'LateralLength',
#        'ProppantPerFoot', 'FluidPerFoot', 'LeftDistance', 'LeftNeighbourType',
#        'RightDistance', 'RightNeighbourType', 'TVD', 'NormalizedOilEUR',
#        'NormalizedGasEUR'],
#       dtype='object')

# %%
result = ddf.groupby('FormationAlias').WellID.nunique()
computed_result = result.compute()
computed_result
# Out:
# FormationAlias
# NIOBRARA    6917
# CODELL      2289
# Name: WellID, dtype: int64

# %% [markdown]
# You can set an index column using the .set_index(column_name) method. This operation is expensive though

# %%
mean_dask = ddf['BVHH'].mean()
mean_dask.compute()
# Out:
# np.float64(1.031013138081877)

# %%
# Dask can utilize multiple cores, enhancing performance for large data
ddf['NormalizedOilEUR power'] = ddf['NormalizedOilEUR'].map_partitions(lambda df: df * 2) #apply in pandas
ddf.compute()
# Out:
#           WellID      BVHH FormationAlias       NioGOR       CodGOR  \
# 0      500109742  1.105028       NIOBRARA  1687.414535          NaN
# 1      500109753  0.644480       NIOBRARA  2267.667384          NaN
# 2      500109754  0.620268       NIOBRARA  2368.236087          NaN
# 3      500109760  0.649670       NIOBRARA   333.876618          NaN
# 4      500109772  1.423475       NIOBRARA  3608.065949  3199.962930
# ...          ...       ...            ...          ...          ...
# 9201  4902129125       NaN         CODELL  1190.578936   949.853322
# 9202  4902129224       NaN         CODELL          NaN   397.429199
# 9203  4902129225       NaN         CODELL          NaN   336.475960
# 9204  4902129416       NaN         CODELL          NaN   519.208816
# 9205  4902129425       NaN         CODELL          NaN   472.746854
#
#       LateralLength  ProppantPerFoot  FluidPerFoot  LeftDistance  \
# 0            8084.0      1256.308758   1234.370856           NaN
# 1            3912.0       742.842536    784.000000           NaN
# 2            4137.0       912.738700   1127.047136        1330.0
# 3            4161.0       914.683970    691.026676           NaN
# 4            4418.0       747.271842    928.239928           NaN
# ...             ...              ...           ...           ...
# 9201         8583.0      1393.493883   2462.864733        1325.0
# 9202         9882.0      2758.550901   1364.672738           NaN
# 9203         9581.0      2531.677278   1290.361340           NaN
# 9204         9768.0      1536.333026   1992.940418           NaN
# 9205         9947.0       544.153011    353.446868           NaN
#
#      LeftNeighbourType  RightDistance RightNeighbourType     TVD  \
# 0          NoNeighbour            NaN        NoNeighbour  7501.0
# 1          NoNeighbour         1330.0        Codeveloped  7551.0
# 2          Codeveloped            NaN        NoNeighbour  7594.0
# 3          NoNeighbour            NaN        NoNeighbour  7391.0
# 4          NoNeighbour            NaN        NoNeighbour  7838.0
# ...                ...            ...                ...     ...
# 9201       Codeveloped            NaN        NoNeighbour  8613.0
# 9202       NoNeighbour            NaN        NoNeighbour  7631.0
# 9203       NoNeighbour            NaN        NoNeighbour  7592.0
# 9204       NoNeighbour            NaN        NoNeighbour  7783.0
# 9205       NoNeighbour            NaN        NoNeighbour  8029.0
#
#       NormalizedOilEUR  NormalizedGasEUR  NormalizedOilEUR power
# 0            15.234785         37.674048               30.469570
# 1             5.327198         11.627301               10.654397
# 2             5.629925         14.544356               11.259850
# 3             8.240087          7.012257               16.480173
# 4            15.374830         51.169534               30.749660
# ...                ...               ...                     ...
# 9201         18.513690         15.231737               37.027380
# 9202         33.791844         12.357013               67.583688
# 9203         27.725394         14.413422               55.450788
# 9204         36.654894         35.377252               73.309787
# 9205         21.549311         11.413492               43.098623
#
# [9206 rows x 16 columns]

# %%
result = ddf.groupby('FormationAlias').mean() #'numeric_only=False' is not implemented in Dask.
result.npartitions
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result = ddf.groupby('FormationAlias').mean() #'numeric_only=False' is not implemented in Dask.
#       2 result.npartitions
#
# File ~\anaconda3\envs\myvenv2\Lib\site-packages\dask\utils.py:265, in _deprecated_kwarg.<locals>._deprecated_kwarg.<locals>.wrapper(*args, **kwargs)
#     263         raise TypeError(msg)
#     264     kwargs[new_arg_name] = new_arg_value
# --> 265 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\myvenv2\Lib\site-packages\dask\dataframe\groupby.py:295, in numeric_only_not_implemented.<locals>.wrapper(self, *args, **kwargs)
#     293         if not self._all_numeric():
#     294             if numeric_only is False or numeric_only is no_default:
# --> 295                 raise NotImplementedError(
#     296                     "'numeric_only=False' is not implemented in Dask."
#     297                 )
#     298 return func(self, *args, **kwargs)
#
# NotImplementedError: 'numeric_only=False' is not implemented in Dask.

# %%
numeric_cols = ddf.select_dtypes(include='number').columns
ddf[numeric_cols].groupby(ddf['FormationAlias']).mean().compute()
# Out:
#                       WellID      BVHH       NioGOR       CodGOR  \
# FormationAlias
# CODELL          1.154323e+09  0.864766  3732.618172  3537.690482
# NIOBRARA        5.740835e+08  1.086811  5018.081961  4490.776987
#
#                 LateralLength  ProppantPerFoot  FluidPerFoot  LeftDistance  \
# FormationAlias
# CODELL            7272.412740       859.162343    892.336873   1325.292715
# NIOBRARA          6870.006702      1065.527839   1083.444610    732.328125
#
#                 RightDistance          TVD  NormalizedOilEUR  \
# FormationAlias
# CODELL            1354.085865  7474.564045         18.985596
# NIOBRARA           741.031915  6860.234853         19.049792
#
#                 NormalizedGasEUR  NormalizedOilEUR power
# FormationAlias
# CODELL                101.820300               37.971193
# NIOBRARA              107.119895               38.099585

# %%
numeric_cols = ddf.select_dtypes(include='number').columns
ddf.groupby('FormationAlias').agg({col: 'var' for col in numeric_cols}).compute()
# Out:
#                       WellID      BVHH        NioGOR        CodGOR  \
# FormationAlias
# NIOBRARA       -1.265199e+15  0.144409  2.033189e+08  1.199597e+07
# CODELL          1.241200e+15  0.079999  2.058715e+07  7.626717e+06
#
#                 LateralLength  ProppantPerFoot   FluidPerFoot  LeftDistance  \
# FormationAlias
# NIOBRARA         7.064571e+06    303962.990319  353252.088376  7.356659e+05
# CODELL           7.280603e+06    179601.100984  495867.820708  1.002601e+06
#
#                 RightDistance            TVD  NormalizedOilEUR  \
# FormationAlias
# NIOBRARA         7.585181e+05  308180.421812         66.371054
# CODELL           1.091862e+06  314012.781980         69.050295
#
#                 NormalizedGasEUR  NormalizedOilEUR power
# FormationAlias
# NIOBRARA             4350.173439              265.484215
# CODELL               4474.293621              276.201180

# %%
ddf.groupby('FormationAlias').count().compute()
# Out:
#                 WellID  BVHH  NioGOR  CodGOR  LateralLength  ProppantPerFoot  \
# FormationAlias
# CODELL            2289  1901    2157    2146           2289             2260
# NIOBRARA          6917  5664    6552    5392           6917             6714
#
#                 FluidPerFoot  LeftDistance  LeftNeighbourType  RightDistance  \
# FormationAlias
# CODELL                  2251          1510               2289           1514
# NIOBRARA                6691          5248               6917           5264
#
#                 RightNeighbourType   TVD  NormalizedOilEUR  NormalizedGasEUR  \
# FormationAlias
# CODELL                        2289  2225              2289              2289
# NIOBRARA                      6917  6668              6917              6917
#
#                 NormalizedOilEUR power
# FormationAlias
# CODELL                            2289
# NIOBRARA                          6917

# %%
filtered_df = ddf[ddf['LateralLength'] > 7210].count()
filtered_df.compute()
# Out:
# WellID                4119
# BVHH                  2821
# FormationAlias        4119
# NioGOR                3739
# CodGOR                3268
# LateralLength         4119
# ProppantPerFoot       4098
# FluidPerFoot          4089
# LeftDistance          2967
# LeftNeighbourType     4119
# RightDistance         2952
# RightNeighbourType    4119
# TVD                   3870
# NormalizedOilEUR      4119
# NormalizedGasEUR      4119
# dtype: int64

# %% [markdown]
# ### Special APIs in Dask

# %%
ddf = ddf.map_partitions(lambda df: df['NormalizedGasEUR'] * 2)
ddf.compute() 
# Apply a function to each partition (chunk) of the DataFrame independently.
# very powerful for custom transformations or applying operations that aren't natively supported by Dask.
# Out:
# 0        75.348095
# 1        23.254601
# 2        29.088712
# 3        14.024513
# 4       102.339067
#            ...
# 9201     30.463474
# 9202     24.714026
# 9203     28.826845
# 9204     70.754505
# 9205     22.826983
# Name: NormalizedGasEUR, Length: 9206, dtype: float64

# %%
ddf._meta
# Out:
# Series([], Name: NormalizedGasEUR, dtype: float64)

# %%
ddf = ddf.repartition(npartitions=10)

# %%
ddf.npartitions
# Out:
# 10

# %% [markdown]
# ### Distributed Computing
# Dask can run across multiple machines in a cluster.

# %%
pip install dask distributed
# Out:
# Requirement already satisfied: dask in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (2024.9.1)
# Requirement already satisfied: distributed in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (2024.9.1)
# Requirement already satisfied: click>=8.1 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (24.1)
# Requirement already satisfied: partd>=1.4.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask) (8.5.0)
# Requirement already satisfied: jinja2>=2.10.3 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (6.4.1)
# Requirement already satisfied: urllib3>=1.26.5 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (2.2.3)
# Requirement already satisfied: zict>=3.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed) (3.0.0)
# Requirement already satisfied: colorama in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from click>=8.1->dask) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from importlib-metadata>=4.13.0->dask) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from jinja2>=2.10.3->distributed) (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dask.distributed import Client

# Start a local cluster
client = Client()
print(client)
# Out:
# D:\Users\yara.maraey\anaconda\envs\myvenv\Lib\site-packages\distributed\node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 59458 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:59461' processes=5 threads=20, memory=15.69 GiB>

# %%
pip install dask[distributed]
# Out:
# Requirement already satisfied: dask[distributed] in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (2024.9.1)
# Requirement already satisfied: click>=8.1 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (24.1)
# Requirement already satisfied: partd>=1.4.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (8.5.0)
# Requirement already satisfied: distributed==2024.9.1 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from dask[distributed]) (2024.9.1)
# Requirement already satisfied: jinja2>=2.10.3 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (6.4.1)
# Requirement already satisfied: urllib3>=1.26.5 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (2.2.3)
# Requirement already satisfied: zict>=3.0.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from distributed==2024.9.1->dask[distributed]) (3.0.0)
# Requirement already satisfied: colorama in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from click>=8.1->dask[distributed]) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from importlib-metadata>=4.13.0->dask[distributed]) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\yara.maraey\anaconda\envs\myvenv\lib\site-packages (from jinja2>=2.10.3->distributed==2024.9.1->dask[distributed]) (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dask.dataframe as dd
from dask.distributed import Client
import time
# Connect to the Dask cluster 
client = Client('tcp://127.0.0.1:59461')  # Change 'scheduler-address' as needed
start_time = time.time()
mean_bvhh = ddf['BVHH'].mean().compute()
end_time = time.time()
time_taken = end_time - start_time

print(f"Mean BVHH: {mean_bvhh}")
print(f"Time taken: {time_taken:.4f} seconds")

# shut down the client after computation
client.close()
# Out:
# Mean BVHH: 1.031013138081877
# Time taken: 0.7508 seconds

# %%
start_time = time.time()
mean_bvh = ddf['BVHH'].mean().compute()
end_time = time.time()
time_taken = end_time - start_time

print(f"Mean BVHH: {mean_bvh}")
print(f"Time taken: {time_taken:.4f} seconds")
# Out:
# Mean BVHH: 1.031013138081877
# Time taken: 1.1556 seconds

# %%
df_dask_persisted = ddf.persist() # Persist data in memory for faster repeated computations

# %%
# Save to Parquet format, which is optimized for performance
combined_df.to_parquet('output.parquet')
